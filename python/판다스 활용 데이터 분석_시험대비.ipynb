# %% [markdown]
# ### 판다스 활용 데이터 분석

# %% [markdown]
# 1. 키보드로 세 수를 입력받고,입력받은 세 수를 리스트에 저장하시오. 그 후 리스트에 저장된 수 중 가장 큰 수와 가장 작은 수의 차를 출력하시오.

# %%
#1번 문제 풀이 작성
inputList = []
inputData1 = int(input('첫번째 수 : '))
inputData2 = int(input('두번째 수 : '))
inputData3 = int(input('세번째 수 : '))
inputList = [inputData1, inputData2, inputData3]

minus = max(inputList) - min(inputList)

print(inputList)
print(minus)
# Out:
# [7, 4, 2]
# 5

# %% [markdown]
# 2. 매개변수로 두 개의 리스트를 받아, 두 개의 리스트에 저장된 모든 데이터의 합을 리턴하는 함수를 작성하시오.
# EX> 두 매개변수 : [1,2,3] , [4,5,6] / 결과 : 21

# %%
#2번 문제 풀이 작성
list1 = [1, 2, 3]
list2 = [4, 5, 6]
print(sum(list1 + list2))
# Out:
# 21

# %% [markdown]
# 3. 매개변수로 두 개의 리스트를 받아, 두 개의 리스트에 중복으로 저장된 데이터만을 갖는  새로운 리스트를 리턴하는 함수를 작성하시오.
# EX> 두 매개변수 : [1,3,5,7,9] , [1,2,3,4,5] / 결과 : [1,3,5]

# %%
#3번 문제 풀이 작성
list3 = [1, 3, 5, 7, 9]
list4 = [1, 2, 3, 4, 5]
list5 = []

for e in list3 :
  for j in list4 :
    if e == j :
      list5.append(e)

print(list5)
# Out:
# [1, 3, 5]

# %% [markdown]
# 4. 이름, 나이, 국어점수, 영어점수, 국어점수를 데이터로 갖는 student 딕셔너리를 만드시오. 각 데이터는 키보드로 입력받아 저장하시오.

# %%
#4번 문제 풀이 작성
student = {
  '이름' : input('이름 입력 : '),
  '나이' : input('나이 입력 : '),
  '국어점수' : int(input('국어점수 입력 : ')),
  '영어점수' : int(input('영어점수 입력 : ')),
  '수학점수' : int(input('수학점수 입력 : '))
}

print(student)
# Out:
# {'이름': '유유', '나이': '32', '국어점수': 70, '영어점수': 70, '수학점수': 80}

# %% [markdown]
# 5. 4번 문제에서 만든 딕셔너리 데이터에 총점 데이터를 추가하시오. 총점 데이터는 국어,영어, 수학점수의 합으로 들어가야합니다.

# %%
#5번 문제 풀이 작성
totalScore = student['국어점수'] + student['영어점수'] + student['수학점수']
print(totalScore)
student['총점'] = totalScore 

print(student)
# Out:
# 220
# {'이름': '유유', '나이': '32', '국어점수': 70, '영어점수': 70, '수학점수': 80, '총점': 220}

# %% [markdown]
# 6. 아래 딕셔너리 데이터에 stu_grade라는 키를 추가하고, 해당 키의  데이터로  점수(stu_score)에 따른 등급 데이터를 저장하시오.
# 90 <= 점수      : A등급
# 80 <= 점수 < 90 : B등급
# 70 <= 점수 < 80 : C등급
#       점수 < 70 : D등급

# %%
class_room_data = {
    'stu_no' : [1, 2, 3, 4, 5],
    'stu_name' : ['김자바', '이자바', '박자바', '최자바', '정자바'],
    'stu_score' : [85, 65, 70, 80, 95]
}


#6번 문제 풀이 작성
class_room_data['stu_grade']=[]

for e in class_room_data['stu_score'] :
  if 90 <= e :
    class_room_data['stu_grade'].append('A등급')
  elif 80 <= e & e < 90 :
    class_room_data['stu_grade'].append('B등급')
  elif 70 <= e & e < 80 :
    class_room_data['stu_grade'].append('C등급')
  else :
    class_room_data['stu_grade'].append('D등급')
  

print(class_room_data)
# Out:
# {'stu_no': [1, 2, 3, 4, 5], 'stu_name': ['김자바', '이자바', '박자바', '최자바', '정자바'], 'stu_score': [85, 65, 70, 80, 95], 'stu_grade': ['B등급', 'D등급', 'C등급', 'B등급', 'A등급']}
